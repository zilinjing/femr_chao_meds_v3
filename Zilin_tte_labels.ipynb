# %% [markdown]
# # Pipeline on Synthetic Data, Mimicking the structure of the real data

# %%
import pandas as pd
import numpy as np
import os
import uuid
from datetime import datetime, timedelta

def generate_synthetic_data(phenotype_name, cases_csv='yl_pheno_cases.csv'):
    
    print("--- Generating synthetic data for demonstration ---")
    data_path = 'data'
    phenotype_folder_sanitized = phenotype_name.replace(' Cases', '').replace(' ', '_')
    phenotype_path = os.path.join(data_path, phenotype_folder_sanitized)
    os.makedirs(phenotype_path, exist_ok=True)

    cases_df = pd.read_csv(cases_csv)
    phenotype_cases = cases_df[cases_df['cohort_name'] == phenotype_name]
    case_ids = phenotype_cases['subject_id'].unique()

    subject_ids = np.concatenate([
        np.random.choice(case_ids, size=int(len(case_ids) * 0.7), replace=True),
        [np.random.randint(1000000, 20000000) for _ in range(50)]
    ])

    splits = ['train', 'tuning', 'held_out']

    for split in splits:
        split_ids = np.random.choice(subject_ids, size=200, replace=False)
        
        prediction_times = [
            datetime(2022, 1, 1) - timedelta(days=np.random.randint(1, 365*5))
            for _ in range(200)
        ]
        
        df = pd.DataFrame({
            'subject_id': split_ids,
            'prediction_time': prediction_times,
            'boolean_value': np.random.choice([True, False], size=200),
            'split': split
        })
        
        file_path = os.path.join(phenotype_path, f'{split}.parquet')
        df.to_parquet(file_path)
        print(f"Generated synthetic file: {file_path}")

def generate_time_to_event_labels(phenotype_folder, prediction_df, cohort_info_df):
    
    phenotype_cases_df = cohort_info_df[cohort_info_df['phenotype_folder'] == phenotype_folder].copy()

    merged_df = pd.merge(prediction_df, phenotype_cases_df, on='subject_id', how='left')
    
    merged_df['prediction_time'] = pd.to_datetime(merged_df['prediction_time'])

    merged_df['event_observed'] = merged_df['cohort_start_date'].notna()

    merged_df['time_to_event_hours'] = np.where(
        merged_df['event_observed'],
        (merged_df['cohort_start_date'] - merged_df['prediction_time']).dt.total_seconds() / 3600,
        (merged_df['cohort_end_date'] - merged_df['prediction_time']).dt.total_seconds() / 3600
    )
    
    return merged_df.drop(columns=['cohort_name', 'cohort_start_date', 'cohort_end_date', 'phenotype_folder'], errors='ignore')

if __name__ == "__main__":
    cases_csv_path = 'yl_pheno_cases.csv'
    if not os.path.exists(cases_csv_path):
        print(f"Error: The file '{cases_csv_path}' was not found.")
        print("Please ensure 'yl_pheno_cases.csv' is in the same directory as the script.")
    else:
        cases_df = pd.read_csv(cases_csv_path)
        original_phenotypes = cases_df['cohort_name'].unique()
        
        # First, generate synthetic data for all phenotypes
        for phenotype_name in original_phenotypes:
            generate_synthetic_data(phenotype_name)

        # Now, process the generated data
        cases_df['phenotype_folder'] = cases_df['cohort_name'].str.replace(' Cases', '', regex=False).str.replace(' ', '_', regex=False)
        cases_df['cohort_start_date'] = pd.to_datetime(cases_df['cohort_start_date'])
        cases_df['cohort_end_date'] = pd.to_datetime(cases_df['cohort_end_date'])

        unique_phenotype_folders = cases_df['phenotype_folder'].unique()

        data_path = 'data'
        splits = ['train', 'tuning', 'held_out']

        for phenotype_folder in unique_phenotype_folders:
            print(f"\n--- Processing phenotype: {phenotype_folder} ---")
            
            for split in splits:
                file_path = os.path.join(data_path, phenotype_folder, f"{split}.parquet")

                if not os.path.exists(file_path):
                    print(f"Skipping {file_path} - file not found after generation.")
                    continue
                    
                print(f"  - Processing split: {split}")
                
                prediction_df = pd.read_parquet(file_path)

                labeled_df = generate_time_to_event_labels(phenotype_folder, prediction_df, cases_df)
                
                print(f"    - Sample result for {split} split:")
                print(labeled_df[['subject_id', 'prediction_time', 'time_to_event_hours', 'event_observed']].head())

                output_path = os.path.join(data_path, phenotype_folder, f"{split}_with_labels.parquet")
                labeled_df.to_parquet(output_path)
                print(f"    - Saved results to {output_path}")

# %% [markdown]
# # Pipeline on Real Data

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime, timedelta
import sys


def generate_time_to_event_labels(phenotype_folder, prediction_df, cohort_info_df,last_event_df):
    '''
    phenotype_folder: task name
    cohort_info_df: 
        - phenotype_folder: str
        - cohort_name: str
        - cohort_start_date: datetime
        - cohort_end_date: datetime
        
    prediction_df: 
        - subject_id: str
        - prediction_time: datetime
        - boolean_value: 0/1
        - split: train/tuning/held_out
    last_event_df:
        - subject_id: str
        - last_event_time: datetime
    '''
    
    phenotype_cases_df = cohort_info_df[cohort_info_df['phenotype_folder'] == phenotype_folder].copy()

    merged_df = pd.merge(prediction_df, phenotype_cases_df, on='subject_id', how='left')
    # print(merged_df)

    
    merged_df['prediction_time'] = pd.to_datetime(merged_df['prediction_time'])

    merged_df['event_observed'] = merged_df['cohort_start_date'].notna()
    # print(merged_df['event_observed'].value_counts())

    merged_df['time_to_event_hours'] = np.where(
        merged_df['event_observed'],
        (merged_df['cohort_start_date'] - merged_df['prediction_time']).dt.total_seconds() / 3600,
        (merged_df['cohort_end_date'] - merged_df['prediction_time']).dt.total_seconds() / 3600
    )
    negative_tte = merged_df[(merged_df['time_to_event_hours']<0) | (merged_df['time_to_event_hours'].isna())]
    if len(negative_tte) > 0:
        print("False Labeling")
        print(merged_df)
        print(f"Warning: {len(negative_tte)} negative time to event hours found")
        print(negative_tte)
        sys.exit()

    # assert merged_df['time_to_event_hours'].min() >= 0, "Time to event hours is negative"
    # sys.exit()
    return merged_df.drop(columns=['cohort_name', 'cohort_start_date', 'cohort_end_date', 'phenotype_folder'], errors='ignore')

if __name__ == "__main__":
    cases_csv_path = '/data/processed_datasets/processed_datasets/ehr_foundation_data/ohdsi_cumc_deid/ohdsi_cumc_deid_2023q4r3_v3_mapped/task_labels/tte_task_labels/yl_pheno_cases.csv'
    data_path = '/data/processed_datasets/processed_datasets/ehr_foundation_data/ohdsi_cumc_deid/ohdsi_cumc_deid_2023q4r3_v3_mapped/task_labels/phenotype_sample'
    last_event_path = '/data/processed_datasets/processed_datasets/ehr_foundation_data/ohdsi_cumc_deid/ohdsi_cumc_deid_2023q4r3_v3_mapped/task_labels/tte_task_labels/last_event_times.csv'
    output_dir = '/data/processed_datasets/processed_datasets/ehr_foundation_data/ohdsi_cumc_deid/ohdsi_cumc_deid_2023q4r3_v3_mapped/task_labels/tte_task_labels'

    if not os.path.exists(cases_csv_path):
        print(f"Error: The file '{cases_csv_path}' was not found.")
        print("Please ensure 'yl_pheno_cases.csv' is in the same directory as the script.")
    elif not os.path.exists(data_path):
        print(f"Error: The folder '{data_path}' was not found.")
        print("Please ensure the root 'data' directory with phenotype subfolders exists.")
    else:
        cases_df = pd.read_csv(cases_csv_path)
        cases_df['phenotype_folder'] = cases_df['cohort_name'].str.replace(' Cases', '', regex=False).str.replace(' ', '_', regex=False)
        cases_df['cohort_start_date'] = pd.to_datetime(cases_df['cohort_start_date'])
        cases_df['cohort_end_date'] = pd.to_datetime(cases_df['cohort_end_date'])

        # Get a list of phenotype folders that already exist in the 'data' directory
        # unique_phenotype_folders = [d for d in os.listdir(data_path) if (os.path.isdir(os.path.join(data_path, d)) and d not in ["AMI","Ischemic_Stroke"] ) ]
        unique_phenotype_folders = ["CLL"]
        splits = ['train', 'tuning', 'held_out']
        last_event_df = pd.read_csv(last_event_path)

        for phenotype_folder in unique_phenotype_folders:
            print(f"\n--- Processing phenotype: {phenotype_folder} ---")
            
            for split in splits:
                file_path = os.path.join(data_path, phenotype_folder, f"{split}.parquet")

                if not os.path.exists(file_path):
                    print(f"Skipping {file_path} - file not found.")
                    continue
                    
                print(f"  - Processing split: {split}")
                
                prediction_df = pd.read_parquet(file_path)

                labeled_df = generate_time_to_event_labels(phenotype_folder, prediction_df, cases_df,last_event_df)
                
                # print(f"    - Sample result for {split} split:")
                # print(labeled_df[['subject_id', 'prediction_time', 'time_to_event_hours', 'event_observed']].head())

                os.makedirs(os.path.join(output_dir, phenotype_folder), exist_ok=True)
                output_path = os.path.join(output_dir, phenotype_folder, f"tte_{split}.parquet")
                labeled_df.to_parquet(output_path)
                print(f"    - Saved results to {output_path}")

# %%
import meds_reader
import csv

meds_reader_path = "/data/processed_datasets/processed_datasets/ehr_foundation_data/ohdsi_cumc_deid/ohdsi_cumc_deid_2023q4r3_v3_mapped/post_transform_meds_reader"
database = meds_reader.SubjectDatabase(meds_reader_path)

def extract_last(subjects):
    return [(subject.subject_id, subject.events[-1].time if subject.events else "") for subject in subjects]

# Process in parallel across threads
results = database.map(extract_last)

with open("last_event_times.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["subject_id", "last_event_time"])
    for batch in results:
        for subj_id, last_time in batch:
            writer.writerow([subj_id, last_time])

# %%
import meds_reader
from collections import Counter

# Load database
meds_reader_path = "/data/processed_datasets/processed_datasets/ehr_foundation_data/ohdsi_cumc_deid/ohdsi_cumc_deid_2023q4r3_v3_mapped/post_transform_meds_reader"
database = meds_reader.SubjectDatabase(meds_reader_path)

last_event_codes = []

# Iterate through all subjects
for subject_id in database:
    subject = database[subject_id]
    if subject.events:  # If this subject has events
        last_event = subject.events[-1]  # Last event in chronological order
        if last_event.code == "CMS Place of Service/12":
            print(subject_id)
            for event in subject.events:
                print(event)
            print()
            continue
            # print(f"Last event is {last_event}")
        last_event_codes.append(last_event.code)

# Count top 10 codes
code_counts = Counter(last_event_codes)
top_10 = code_counts.most_common(10)

print("Top 10 last event codes:")
for code, count in top_10:
    print(f"{code}: {count}")
# Out:
# 12
# Event(time=1963-05-10 00:00:00, code=Ethnicity/Not Hispanic, ...)
# Event(time=1963-05-10 00:00:00, code=Gender/F, ...)
# Event(time=1963-05-10 00:00:00, code=MEDS_BIRTH, ...)
# Event(time=1963-05-10 00:00:00, code=Race/3, ...)
# Event(time=2012-08-12 12:44:00.100000, code=Visit/OP, ...)
# Event(time=2012-08-12 12:44:00.100010, code=PCORNet/Generic-NI, ...)
# Event(time=2020-06-25 00:00:00, code=CPT4/73140, ...)
# Event(time=2020-06-25 00:00:00, code=ICD10CM/M19.042, ...)
# Event(time=2020-06-25 00:00:00, code=ICD10CM/S69.92XA, ...)
# Event(time=2020-06-25 10:06:00.100020, code=ICD10CM/S69.92XA, ...)
# Event(time=2020-06-25 10:06:00.100020, code=Visit/ER, ...)
# Event(time=2020-06-25 10:37:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2020-06-25 10:37:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-06-25 10:37:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-06-25 10:37:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-06-25 10:37:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2020-06-25 11:05:00, code=CPT4/73140, ...)
# Event(time=2020-06-25 11:29:00.100030, code=CMS Place of Service/12, ...)
# Event(time=2020-06-25 11:29:00.100030, code=ICD10CM/E11.9, ...)
# Event(time=2020-06-25 11:29:00.100030, code=ICD10CM/I10, ...)
# Event(time=2020-06-25 11:29:00.100030, code=ICD10CM/S69.92XA, ...)
# Event(time=2020-06-25 11:29:00.100030, code=ICD10CM/W23.0XXA, ...)
# Event(time=2020-06-25 11:29:00.100030, code=ICD10CM/Y92.238, ...)
# Event(time=2020-06-25 11:29:00.100030, code=ICD10CM/Y93.89, ...)
# Event(time=2020-06-25 11:29:00.100030, code=ICD10CM/Y99.0, ...)
# Event(time=2022-09-22 00:00:00, code=CVX/208, ...)
# Event(time=2022-09-22 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2022-09-25 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2022-09-25 10:00:00, code=LOINC/13955-0, ...)
# Event(time=2022-09-25 10:00:00, code=LOINC/64084-7//UCUM/[iU]/mL, ...)
# Event(time=2022-09-25 10:00:00, code=LOINC/71773-6, ...)
# Event(time=2022-09-25 10:00:00, code=LOINC/71774-4//UCUM/[iU]/mL, ...)
# Event(time=2022-09-25 10:00:00, code=LOINC/71776-9//UCUM/[iU]/mL, ...)
# Event(time=2022-09-25 10:00:00, code=LOINC/88517-8//UCUM/[iU]/mL, ...)
# Event(time=2022-10-13 00:00:00, code=CVX/208, ...)
# Event(time=2022-10-13 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2023-01-04 00:00:00, code=ICD10CM/E11.9, ...)
# Event(time=2023-01-05 00:00:00, code=ICD10CM/U07.1, ...)
# Event(time=2023-01-05 08:40:40, code=Visit/OP, ...)
# Event(time=2023-01-05 08:55:40, code=PCORNet/Generic-NI, ...)
# Event(time=2023-01-05 11:07:00, code=LOINC/34487-9, ...)
# Event(time=2023-01-05 11:07:00, code=LOINC/40982-1, ...)
# Event(time=2023-01-05 11:07:00, code=LOINC/94500-6, ...)
# Event(time=2023-08-13 00:00:00, code=CPT4/73590, ...)
# Event(time=2023-08-13 00:00:00, code=CPT4/73590, ...)
# Event(time=2023-08-13 00:00:00, code=ICD10CM/M79.662, ...)
# Event(time=2023-08-13 00:00:00, code=ICD10CM/M79.89, ...)
# Event(time=2023-08-13 00:00:00, code=ICD10CM/R22.42, ...)
# Event(time=2023-08-13 00:00:00, code=ICD10CM/S80.12XA, ...)
# Event(time=2023-08-13 00:00:00, code=ICD10CM/S80.12XA, ...)
# Event(time=2023-08-13 10:37:00, code=ICD10CM/E11.9, ...)
# Event(time=2023-08-13 10:37:00, code=ICD10CM/E78.5, ...)
# Event(time=2023-08-13 10:37:00, code=ICD10CM/I10, ...)
# Event(time=2023-08-13 10:37:00, code=ICD10CM/M79.605, ...)
# Event(time=2023-08-13 10:37:00, code=ICD10CM/M79.605, ...)
# Event(time=2023-08-13 10:37:00, code=ICD10CM/S80.12XA, ...)
# Event(time=2023-08-13 10:43:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-08-13 10:43:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-08-13 10:43:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-08-13 10:43:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2023-08-13 10:43:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-08-13 10:43:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-08-13 10:43:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-08-13 10:43:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-08-13 11:28:00, code=CPT4/73590, ...)
# Event(time=2023-08-13 11:32:00, code=ICD10CM/E11.9, ...)
# Event(time=2023-08-13 11:32:00, code=ICD10CM/E78.5, ...)
# Event(time=2023-08-13 11:32:00, code=ICD10CM/I10, ...)
# Event(time=2023-08-13 11:32:00, code=ICD10CM/M79.605, ...)
# Event(time=2023-08-13 11:32:00, code=ICD10CM/M79.605, ...)
# Event(time=2023-08-13 11:32:00, code=ICD10CM/S80.12XA, ...)
# Event(time=2023-08-13 11:35:00, code=NUCC/261QR0200X, ...)
# Event(time=2023-08-13 11:40:54, code=LOINC/63503-7, ...)
# Event(time=2023-08-13 12:09:00, code=CMS Place of Service/12, ...)
# Event(time=2023-08-13 12:10:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2023-08-13 12:10:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-08-13 12:10:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-08-13 12:10:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-08-13 12:10:00, code=LOINC/9304-7//UCUM//min, ...)
# Event(time=2023-08-13 12:10:00, code=Visit/ER, ...)
# Event(time=2023-08-13 12:21:00, code=RxNorm/313782, ...)
# Event(time=2023-08-13 12:21:00, code=RxNorm/313782, ...)
# Event(time=2023-08-13 12:41:00, code=CMS Place of Service/12, ...)
#
# 14
# Event(time=1991-04-27 00:00:00, code=Ethnicity/Unknown, ...)
# Event(time=1991-04-27 00:00:00, code=Gender/M, ...)
# Event(time=1991-04-27 00:00:00, code=MEDS_BIRTH, ...)
# Event(time=1991-04-27 00:00:00, code=Race/5, ...)
# Event(time=2017-05-16 00:00:00, code=CPT4/88305, ...)
# Event(time=2017-05-16 00:00:00, code=ICD10CM/D22.5, ...)
# Event(time=2017-05-16 00:00:00, code=ICD10CM/D22.61, ...)
# Event(time=2019-09-04 00:00:00, code=CPT4/62270, ...)
# Event(time=2019-09-04 00:00:00, code=CPT4/70450, ...)
# Event(time=2019-09-04 00:00:00, code=ICD10CM/R51, ...)
# Event(time=2019-09-04 20:55:00, code=CPT4/70450, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/14979-9//UCUM/s, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/17861-6//UCUM/mg/dL, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/19123-9//UCUM/mg/dL, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/2028-9//UCUM/mmol/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/20405-7, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/2075-0//UCUM/mmol/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/2160-0//UCUM/mg/dL, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/2345-7//UCUM/mg/dL, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/2756-5, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/2823-3//UCUM/mmol/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/2951-2//UCUM/mmol/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/2965-2, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/3094-0//UCUM/mg/dL, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/3097-3, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/32623-1//UCUM/fL, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/33037-3, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/4544-3//UCUM/%, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5767-9, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5770-3, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5778-6, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5792-7, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5794-3, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5797-6, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5799-2, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5802-4, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5804-0, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/58413-6//UCUM//100.{WBC}, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5902-2//UCUM/s, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/5905-5//UCUM/%, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/6301-6, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/6690-2//UCUM/10*9/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/704-7//UCUM/10*9/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/706-2//UCUM/%, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/711-2//UCUM/10*9/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/713-8//UCUM/%, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/718-7//UCUM/g/dL, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/731-0//UCUM/10*9/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/736-9//UCUM/%, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/742-7//UCUM/10*9/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/751-8//UCUM/10*9/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/770-8//UCUM/%, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/771-6//UCUM/10*9/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/77147-7//UCUM/mL/min/1.73.m2, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/77147-7//UCUM/mL/min/1.73.m2, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/777-3//UCUM/10*9/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/785-6//UCUM/pg, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/786-4//UCUM/g/dL, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/787-2//UCUM/fL, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/788-0//UCUM/%, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/789-8//UCUM/10*12/L, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/882-1, ...)
# Event(time=2019-09-04 21:00:00, code=LOINC/890-4, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/10328-3//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/10333-3, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/10333-3, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/10335-8, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/10335-8, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/11135-1, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/11135-1, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/12208-5//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/12278-8//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/13517-8//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/13519-4//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/13521-0//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/13529-3//UCUM//100.{WBC}, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/19075-1, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/19075-1, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/19157-7, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/19157-7, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/2342-4//UCUM/mg/dL, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/23904-6//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/2880-3//UCUM/mg/dL, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/34995-1//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/35011-6//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/35017-3//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/35030-6//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/40541-5//UCUM/%, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/664-3, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/792-2//UCUM//uL, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/792-2//UCUM//uL, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/806-0//UCUM//uL, ...)
# Event(time=2019-09-04 23:17:00, code=LOINC/806-0//UCUM//uL, ...)
# Event(time=2021-07-27 00:00:00, code=CVX/207, ...)
# Event(time=2021-08-17 00:00:00, code=CPT4/72040, ...)
# Event(time=2021-08-17 00:00:00, code=CPT4/73030, ...)
# Event(time=2021-08-17 00:00:00, code=ICD10CM/M25.511, ...)
# Event(time=2021-08-17 00:00:00, code=ICD10CM/M25.511, ...)
# Event(time=2021-08-17 00:00:00, code=ICD10CM/M25.511, ...)
# Event(time=2021-08-17 00:00:00, code=ICD10CM/M54.2, ...)
# Event(time=2021-08-17 00:00:00, code=ICD10CM/M54.2, ...)
# Event(time=2021-08-17 00:00:00, code=ICD10CM/M54.2, ...)
# Event(time=2021-08-17 14:20:00, code=ICD10CM/M25.511, ...)
# Event(time=2021-08-17 14:20:00, code=ICD10CM/M25.511, ...)
# Event(time=2021-08-17 14:20:00, code=ICD10CM/M54.2, ...)
# Event(time=2021-08-17 14:20:00, code=ICD10CM/M54.2, ...)
# Event(time=2021-08-17 14:21:00, code=ICD10CM/M25.511, ...)
# Event(time=2021-08-17 14:21:00, code=ICD10CM/M25.511, ...)
# Event(time=2021-08-17 14:21:00, code=ICD10CM/M54.2, ...)
# Event(time=2021-08-17 14:21:00, code=ICD10CM/M54.2, ...)
# Event(time=2021-08-17 14:22:00, code=CPT4/72040, ...)
# Event(time=2021-08-17 14:22:00, code=CPT4/73030, ...)
# Event(time=2021-08-17 14:22:00, code=NUCC/261QR0200X, ...)
# Event(time=2021-08-17 14:22:00, code=NUCC/261QR0200X, ...)
# Event(time=2021-08-17 14:22:38, code=LOINC/63503-7, ...)
# Event(time=2021-08-17 23:59:00, code=CMS Place of Service/12, ...)
# Event(time=2021-08-17 23:59:00, code=CMS Place of Service/12, ...)
#
# 16
# Event(time=1975-07-03 00:00:00, code=Ethnicity/Hispanic, ...)
# Event(time=1975-07-03 00:00:00, code=Gender/F, ...)
# Event(time=1975-07-03 00:00:00, code=MEDS_BIRTH, ...)
# Event(time=1975-07-03 00:00:00, code=Race/Unknown, ...)
# Event(time=2021-10-01 00:00:00, code=CPT4/93010, ...)
# Event(time=2021-10-01 00:00:00, code=ICD10CM/M54.9, ...)
# Event(time=2021-10-01 00:00:00, code=ICD10CM/M54.9, ...)
# Event(time=2021-10-01 00:00:00, code=ICD10CM/R94.31, ...)
# Event(time=2021-10-01 00:00:00, code=LOINC/63503-7, ...)
# Event(time=2021-10-01 00:00:00, code=RxNorm/310798, ...)
# Event(time=2021-10-01 10:44:00, code=ICD10CM/I10, ...)
# Event(time=2021-10-01 10:44:00, code=ICD10CM/M54.6, ...)
# Event(time=2021-10-01 10:44:00, code=ICD10CM/M54.6, ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/29463-7//UCUM/[oz_av], ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/8302-2//UCUM/[in_us], ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2021-10-01 10:56:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2021-10-01 11:01:00, code=CPT4/93000, ...)
# Event(time=2021-10-01 11:06:00, code=CPT4/93000, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/78199-7, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/78199-7, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8625-6//UCUM/ms, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8625-6//UCUM/ms, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8626-4//UCUM/deg, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8626-4//UCUM/deg, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8633-0//UCUM/ms, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8633-0//UCUM/ms, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8634-8//UCUM/ms, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8634-8//UCUM/ms, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8636-3//UCUM/ms, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8636-3//UCUM/ms, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8638-9//UCUM/deg, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8638-9//UCUM/deg, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8894-8, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8894-8, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8897-1, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/8897-1, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/9997-8//UCUM/deg, ...)
# Event(time=2021-10-01 11:06:00, code=LOINC/9997-8//UCUM/deg, ...)
# Event(time=2021-10-01 13:14:00, code=LOINC/29463-7//UCUM/[oz_av], ...)
# Event(time=2021-10-01 13:14:00, code=LOINC/39156-5//UCUM/kg/m2, ...)
# Event(time=2021-10-01 13:14:00, code=LOINC/8277-6//UCUM/m2, ...)
# Event(time=2021-10-01 13:14:00, code=LOINC/8302-2//UCUM/[in_us], ...)
# Event(time=2021-10-01 13:14:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2021-10-01 13:14:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2021-10-01 13:14:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2021-10-01 13:14:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2021-10-01 13:14:00, code=LOINC/9304-7//UCUM//min, ...)
# Event(time=2021-10-01 13:14:00, code=Visit/ER, ...)
# Event(time=2021-10-01 13:30:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2021-10-01 13:30:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2021-10-01 13:30:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2021-10-01 13:30:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2021-10-01 13:30:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2021-10-01 13:30:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2021-10-01 13:30:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2021-10-01 13:30:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2021-10-01 13:33:00, code=CMS Place of Service/12, ...)
#
# 79
# Event(time=1976-07-06 00:00:00, code=Ethnicity/Not Hispanic, ...)
# Event(time=1976-07-06 00:00:00, code=Gender/F, ...)
# Event(time=1976-07-06 00:00:00, code=MEDS_BIRTH, ...)
# Event(time=1976-07-06 00:00:00, code=Race/5, ...)
# Event(time=2009-06-17 00:00:00, code=CPT4/87621, ...)
# Event(time=2009-06-17 00:00:00, code=CPT4/88175, ...)
# Event(time=2009-06-17 00:00:00, code=ICD10CM/Z01.419, ...)
# Event(time=2010-09-02 00:00:00, code=CPT4/87621, ...)
# Event(time=2010-09-02 00:00:00, code=CPT4/88175, ...)
# Event(time=2010-09-02 00:00:00, code=ICD10CM/Z01.419, ...)
# Event(time=2010-09-03 00:00:00, code=CPT4/72192, ...)
# Event(time=2010-09-03 00:00:00, code=CPT4/74150, ...)
# Event(time=2010-09-03 00:00:00, code=ICD10CM/R10.30, ...)
# Event(time=2010-09-03 00:00:00, code=ICD10CM/R31.29, ...)
# Event(time=2010-09-03 11:00:00, code=Visit/OP, ...)
# Event(time=2011-10-09 00:00:00, code=CPT4/87621, ...)
# Event(time=2011-10-09 00:00:00, code=CPT4/88175, ...)
# Event(time=2011-10-09 00:00:00, code=ICD10CM/R87.810, ...)
# Event(time=2011-10-09 00:00:00, code=ICD10CM/Z01.419, ...)
# Event(time=2012-12-08 00:00:00, code=CPT4/87621, ...)
# Event(time=2012-12-08 00:00:00, code=CPT4/88175, ...)
# Event(time=2012-12-08 00:00:00, code=ICD10CM/Z01.419, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/26515-7//UCUM/10*9/L, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/28542-9//UCUM/fL, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/4544-3//UCUM/%, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/58413-6//UCUM//100.{WBC}, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/6690-2//UCUM/10*9/L, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/718-7//UCUM/g/dL, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/771-6//UCUM/10*9/L, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/785-6//UCUM/pg, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/786-4//UCUM/g/dL, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/787-2//UCUM/fL, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/788-0//UCUM/%, ...)
# Event(time=2014-01-01 17:34:00.074256, code=LOINC/789-8//UCUM/10*12/L, ...)
# Event(time=2014-01-01 17:34:00.367856, code=LOINC/48642-3//UCUM/mL/min/1.73.m2, ...)
# Event(time=2014-01-01 17:34:00.367856, code=LOINC/48643-1//UCUM/mL/min/1.73.m2, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/5905-5//UCUM/%, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/704-7//UCUM/10*9/L, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/706-2//UCUM/%, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/711-2//UCUM/10*9/L, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/713-8//UCUM/%, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/731-0//UCUM/10*9/L, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/736-9//UCUM/%, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/742-7//UCUM/10*9/L, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/751-8//UCUM/10*9/L, ...)
# Event(time=2014-01-01 17:34:00.579256, code=LOINC/770-8//UCUM/%, ...)
# Event(time=2014-01-01 17:34:00.711317, code=LOINC/17861-6//UCUM/mg/dL, ...)
# Event(time=2014-01-01 17:34:00.711317, code=LOINC/2028-9//UCUM/mmol/L, ...)
# Event(time=2014-01-01 17:34:00.711317, code=LOINC/2075-0//UCUM/mmol/L, ...)
# Event(time=2014-01-01 17:34:00.711317, code=LOINC/2160-0//UCUM/mg/dL, ...)
# Event(time=2014-01-01 17:34:00.711317, code=LOINC/2345-7//UCUM/mg/dL, ...)
# Event(time=2014-01-01 17:34:00.711317, code=LOINC/2823-3//UCUM/mmol/L, ...)
# Event(time=2014-01-01 17:34:00.711317, code=LOINC/2951-2//UCUM/mmol/L, ...)
# Event(time=2014-01-01 17:34:00.711317, code=LOINC/3094-0//UCUM/mg/dL, ...)
# Event(time=2014-01-01 17:34:00.711317, code=LOINC/33037-3, ...)
# Event(time=2014-01-01 17:34:00.793493, code=LOINC/1798-8//UCUM/[iU]/L, ...)
# Event(time=2014-01-01 17:34:00.883864, code=LOINC/1988-5//UCUM/mg/L, ...)
# Event(time=2014-01-01 17:34:00.957264, code=LOINC/1742-6//UCUM/[iU]/L, ...)
# Event(time=2014-01-01 17:34:00.957264, code=LOINC/1751-7//UCUM/g/dL, ...)
# Event(time=2014-01-01 17:34:00.957264, code=LOINC/1920-8//UCUM/[iU]/L, ...)
# Event(time=2014-01-01 17:34:00.957264, code=LOINC/1968-7//UCUM/mg/dL, ...)
# Event(time=2014-01-01 17:34:00.957264, code=LOINC/1971-1//UCUM/mg/dL, ...)
# Event(time=2014-01-01 17:34:00.957264, code=LOINC/1975-2//UCUM/mg/dL, ...)
# Event(time=2014-01-01 17:34:00.957264, code=LOINC/2336-6//UCUM/g/dL, ...)
# Event(time=2014-01-01 17:34:00.957264, code=LOINC/2885-2//UCUM/g/dL, ...)
# Event(time=2014-01-01 17:34:00.957264, code=LOINC/6768-6//UCUM/[iU]/L, ...)
# Event(time=2014-01-01 20:40:00.100000, code=Visit/OP, ...)
# Event(time=2014-01-01 20:40:00.100010, code=ICD10CM/R10.11, ...)
# Event(time=2014-01-01 20:40:00.100010, code=ICD10CM/R10.12, ...)
# Event(time=2014-01-01 20:40:00.100010, code=PCORNet/Generic-NI, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/19048-8//UCUM//100.{WBC}, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/20570-8//UCUM/%, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/26444-0//UCUM/10*9/L, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/26449-9//UCUM/10*9/L, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/26450-7//UCUM/%, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/26474-7//UCUM/10*9/L, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/26478-8//UCUM/%, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/26499-4//UCUM/10*9/L, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/26511-6//UCUM/%, ...)
# Event(time=2014-01-01 22:03:00, code=LOINC/30392-5//UCUM/10*9/L, ...)
# Event(time=2014-01-01 22:57:00, code=LOINC/48642-3//UCUM/mL/min/1.73.m2, ...)
# Event(time=2014-01-01 22:57:00, code=LOINC/48643-1//UCUM/mL/min/1.73.m2, ...)
# Event(time=2014-01-02 00:00:00, code=CPT4/71020, ...)
# Event(time=2014-01-02 00:00:00, code=CPT4/76700, ...)
# Event(time=2014-01-02 00:00:00, code=ICD10CM/R07.90, ...)
# Event(time=2014-01-02 00:00:00, code=ICD10CM/R10.30, ...)
# Event(time=2014-01-02 12:40:00, code=LOINC/1988-5//UCUM/mg/L, ...)
# Event(time=2014-01-02 13:00:00, code=Visit/OP, ...)
# Event(time=2014-01-02 13:15:00, code=Visit/OP, ...)
# Event(time=2020-02-03 00:00:00, code=CPT4/70487, ...)
# Event(time=2020-02-03 00:00:00, code=CPT4/70491, ...)
# Event(time=2020-02-03 00:00:00, code=CPT4/99233, ...)
# Event(time=2020-02-03 00:00:00, code=ICD10CM/D64.9, ...)
# Event(time=2020-02-03 00:00:00, code=ICD10CM/J98.8, ...)
# Event(time=2020-02-03 00:00:00, code=ICD10CM/K04.7, ...)
# Event(time=2020-02-03 00:00:00, code=ICD10CM/K11.1, ...)
# Event(time=2020-02-03 00:00:00, code=ICD10CM/K12.2, ...)
# Event(time=2020-02-03 00:00:00, code=ICD10CM/R11.2, ...)
# Event(time=2020-02-03 00:00:00, code=ICD10CM/R59.0, ...)
# Event(time=2020-02-03 20:00:00, code=CPT4/70487, ...)
# Event(time=2020-02-03 20:00:00, code=CPT4/70491, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/14576-3, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/1742-6//UCUM/[iU]/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/1751-7//UCUM/g/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/17861-6//UCUM/mg/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/19123-9//UCUM/mg/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/1920-8//UCUM/[iU]/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/1968-7//UCUM/mg/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/1971-1//UCUM/mg/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/1975-2//UCUM/mg/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/2028-9//UCUM/mmol/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/2075-0//UCUM/mmol/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/21198-7//UCUM/10*-3.[iU]/mL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/2160-0//UCUM/mg/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/2336-6//UCUM/g/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/2345-7//UCUM/mg/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/2823-3//UCUM/mmol/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/2885-2//UCUM/g/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/2951-2//UCUM/mmol/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/3094-0//UCUM/mg/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/3097-3//UCUM/{ratio}, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/32623-1//UCUM/fL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/33037-3, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/4544-3//UCUM/%, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/5902-2//UCUM/s, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/5905-5//UCUM/%, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/6301-6, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/6690-2//UCUM/10*9/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/6768-6//UCUM/[iU]/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/704-7//UCUM/10*9/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/706-2//UCUM/%, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/711-2//UCUM/10*9/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/713-8//UCUM/%, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/718-7//UCUM/g/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/731-0//UCUM/10*9/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/736-9//UCUM/%, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/742-7//UCUM/10*9/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/751-8//UCUM/10*9/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/770-8//UCUM/%, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/77147-7//UCUM/mL/min/1.73.m2, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/77147-7//UCUM/mL/min/1.73.m2, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/777-3//UCUM/10*9/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/785-6//UCUM/pg, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/786-4//UCUM/g/dL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/787-2//UCUM/fL, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/788-0//UCUM/%, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/789-8//UCUM/10*12/L, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/882-1, ...)
# Event(time=2020-02-03 20:07:00, code=LOINC/890-4, ...)
# Event(time=2020-02-04 00:13:00, code=LOINC/41653-7//UCUM/mg/dL, ...)
# Event(time=2020-02-04 04:32:00, code=LOINC/41653-7//UCUM/mg/dL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/17861-6//UCUM/mg/dL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/19123-9//UCUM/mg/dL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/2028-9//UCUM/mmol/L, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/2075-0//UCUM/mmol/L, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/2160-0//UCUM/mg/dL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/2345-7//UCUM/mg/dL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/2823-3//UCUM/mmol/L, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/2951-2//UCUM/mmol/L, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/3094-0//UCUM/mg/dL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/3097-3//UCUM/{ratio}, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/32623-1//UCUM/fL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/33037-3, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/4544-3//UCUM/%, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/6690-2//UCUM/10*9/L, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/718-7//UCUM/g/dL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/77147-7//UCUM/mL/min/1.73.m2, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/77147-7//UCUM/mL/min/1.73.m2, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/777-3//UCUM/10*9/L, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/785-6//UCUM/pg, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/786-4//UCUM/g/dL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/787-2//UCUM/fL, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/788-0//UCUM/%, ...)
# Event(time=2020-02-04 04:37:00, code=LOINC/789-8//UCUM/10*12/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/14979-9//UCUM/s, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/1742-6//UCUM/[iU]/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/1751-7//UCUM/g/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/17861-6//UCUM/mg/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/19123-9//UCUM/mg/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/1920-8//UCUM/[iU]/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/1968-7//UCUM/mg/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/1971-1//UCUM/mg/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/1975-2//UCUM/mg/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/2028-9//UCUM/mmol/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/2075-0//UCUM/mmol/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/2160-0//UCUM/mg/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/2336-6//UCUM/g/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/2345-7//UCUM/mg/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/2777-1//UCUM/mg/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/2823-3//UCUM/mmol/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/2885-2//UCUM/g/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/2951-2//UCUM/mmol/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/3094-0//UCUM/mg/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/3097-3//UCUM/{ratio}, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/32623-1//UCUM/fL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/33037-3, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/4544-3//UCUM/%, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/5902-2//UCUM/s, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/5905-5//UCUM/%, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/6301-6, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/6690-2//UCUM/10*9/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/6768-6//UCUM/[iU]/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/704-7//UCUM/10*9/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/706-2//UCUM/%, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/711-2//UCUM/10*9/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/713-8//UCUM/%, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/718-7//UCUM/g/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/731-0//UCUM/10*9/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/736-9//UCUM/%, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/742-7//UCUM/10*9/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/751-8//UCUM/10*9/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/770-8//UCUM/%, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/77147-7//UCUM/mL/min/1.73.m2, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/77147-7//UCUM/mL/min/1.73.m2, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/777-3//UCUM/10*9/L, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/785-6//UCUM/pg, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/786-4//UCUM/g/dL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/787-2//UCUM/fL, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/788-0//UCUM/%, ...)
# Event(time=2020-02-05 00:10:00, code=LOINC/789-8//UCUM/10*12/L, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/32623-1//UCUM/fL, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/4544-3//UCUM/%, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/6690-2//UCUM/10*9/L, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/718-7//UCUM/g/dL, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/777-3//UCUM/10*9/L, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/785-6//UCUM/pg, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/786-4//UCUM/g/dL, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/787-2//UCUM/fL, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/788-0//UCUM/%, ...)
# Event(time=2020-02-05 07:03:00, code=LOINC/789-8//UCUM/10*12/L, ...)
# Event(time=2020-02-07 00:00:00, code=ICD10CM/K12.2, ...)
# Event(time=2020-02-07 00:00:00, code=ICD10CM/K12.2, ...)
# Event(time=2020-02-07 13:31:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-02-07 13:31:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-02-07 13:31:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-02-07 13:46:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2020-02-07 13:46:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-02-07 13:46:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2020-02-07 13:46:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-02-07 13:46:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-02-07 13:46:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-02-07 14:13:00, code=SNOMED/293619005, ...)
# Event(time=2020-02-21 00:00:00, code=ICD10CM/K12.2, ...)
# Event(time=2020-02-21 00:00:00, code=ICD10CM/K12.2, ...)
# Event(time=2020-02-21 10:00:27, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-02-21 10:00:27, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-02-21 10:00:27, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-02-21 10:15:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2020-02-21 10:15:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-02-21 10:15:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2020-02-21 10:15:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-02-21 10:15:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-02-21 10:15:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-04-17 00:00:00, code=ICD10CM/K08.409, ...)
# Event(time=2020-04-17 00:00:00, code=ICD10CM/K08.409, ...)
# Event(time=2020-04-17 13:21:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-04-17 13:21:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-04-17 13:21:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-04-17 13:43:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2020-04-17 13:43:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-04-17 13:43:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2020-04-17 13:43:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-04-17 13:43:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-04-17 13:43:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-04-23 00:00:00, code=ICD10CM/K08.101, ...)
# Event(time=2020-04-23 14:56:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-04-23 14:56:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-04-23 15:02:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2020-04-23 15:02:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-04-23 15:02:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2020-04-23 15:02:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-04-23 15:02:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-04-24 00:00:00, code=ICD10CM/K08.109, ...)
# Event(time=2020-04-24 00:00:00, code=RxNorm/834023, ...)
# Event(time=2020-04-24 13:22:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-04-24 13:22:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-05-08 00:00:00, code=ICD10CM/K08.409, ...)
# Event(time=2020-05-08 00:00:00, code=ICD10CM/K08.409, ...)
# Event(time=2020-05-08 13:58:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-05-08 13:58:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-05-08 13:58:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-05-08 14:21:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2020-05-08 14:21:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-05-08 14:21:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2020-05-08 14:21:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-05-08 14:21:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-05-08 14:21:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-05-25 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2020-05-25 22:58:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-05-25 22:58:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-05-25 22:58:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-06-02 00:00:00, code=RxNorm/308191, ...)
# Event(time=2020-06-02 00:00:00, code=RxNorm/834127, ...)
# Event(time=2020-06-02 00:00:00, code=SNOMED/183644000, ...)
# Event(time=2020-06-02 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2020-06-02 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2020-06-02 13:07:10, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-06-02 13:07:10, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-06-02 13:07:10, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-06-02 13:21:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2020-06-02 13:21:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-06-02 13:21:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2020-06-02 13:21:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-06-02 13:21:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-06-02 13:21:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-06-09 00:00:00, code=ICD10CM/F45.8, ...)
# Event(time=2020-06-09 00:00:00, code=ICD10CM/F45.8, ...)
# Event(time=2020-06-09 13:43:26, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-06-09 13:43:26, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-06-09 13:43:26, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-06-09 13:43:26, code=Visit/OMOP4822458, ...)
# Event(time=2020-06-09 13:58:26, code=PCORNet/Generic-NI, ...)
# Event(time=2020-06-09 14:10:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2020-06-09 14:10:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-06-09 14:10:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2020-06-09 14:10:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-06-09 14:10:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-06-09 14:10:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-07-07 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2020-07-07 00:00:00, code=SNOMED/308273005, ...)
# Event(time=2020-07-07 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2020-07-07 13:10:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-07-07 13:10:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-07-07 13:10:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-07-07 13:10:00, code=Visit/OMOP4822458, ...)
# Event(time=2020-07-07 13:19:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2020-07-07 13:19:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-07-07 13:19:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2020-07-07 13:19:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-07-07 13:19:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-07-07 13:19:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-07-07 13:25:00, code=PCORNet/Generic-NI, ...)
# Event(time=2020-09-26 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2021-01-31 00:00:00, code=CVX/171, ...)
# Event(time=2021-07-18 00:00:00, code=CVX/207, ...)
# Event(time=2021-08-15 00:00:00, code=CVX/207, ...)
# Event(time=2021-09-03 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2021-09-03 00:00:00, code=SNOMED/308273005, ...)
# Event(time=2021-09-03 14:45:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2021-09-03 14:45:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2021-09-03 14:45:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2021-09-03 14:45:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2021-09-03 14:45:00, code=Visit/OP, ...)
# Event(time=2021-09-03 15:12:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2021-09-03 15:12:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2021-09-03 15:12:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2021-09-03 15:12:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2021-09-03 15:12:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2021-09-03 15:12:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2021-09-03 15:12:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2021-09-03 23:59:00, code=CMS Place of Service/12, ...)
# Event(time=2021-09-04 00:00:00, code=ICD10CM/K08.409, ...)
# Event(time=2021-09-04 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2022-03-20 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2023-02-10 00:00:00, code=CPT4/70355, ...)
# Event(time=2023-02-10 00:00:00, code=ICD10CM/K12.2, ...)
# Event(time=2023-02-10 00:00:00, code=ICD10CM/K12.2, ...)
# Event(time=2023-02-10 00:00:00, code=ICD10CM/R68.84, ...)
# Event(time=2023-02-10 12:59:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-10 12:59:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-10 12:59:00, code=Visit/OP, ...)
# Event(time=2023-02-10 13:34:00, code=ICD10CM/K08.409, ...)
# Event(time=2023-02-10 13:34:00, code=ICD10CM/K08.409, ...)
# Event(time=2023-02-10 23:59:00, code=CMS Place of Service/12, ...)
# Event(time=2023-02-17 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2023-02-17 14:10:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-17 14:10:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-17 14:10:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 00:00:00, code=CPT4/41899, ...)
# Event(time=2023-02-24 00:00:00, code=ICD10CM/K08.409, ...)
# Event(time=2023-02-24 00:00:00, code=ICD10CM/K08.409, ...)
# Event(time=2023-02-24 00:00:00, code=RxNorm/1049221, ...)
# Event(time=2023-02-24 00:00:00, code=RxNorm/1049221, ...)
# Event(time=2023-02-24 00:00:00, code=RxNorm/198440, ...)
# Event(time=2023-02-24 00:00:00, code=RxNorm/308192, ...)
# Event(time=2023-02-24 00:00:00, code=RxNorm/834127, ...)
# Event(time=2023-02-24 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2023-02-24 07:59:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2023-02-24 07:59:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 07:59:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 07:59:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 07:59:00, code=LOINC/9304-7//UCUM//min, ...)
# Event(time=2023-02-24 07:59:00, code=Visit/OP, ...)
# Event(time=2023-02-24 08:53:00, code=RxNorm/847630, ...)
# Event(time=2023-02-24 08:56:24, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 08:56:24, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 08:56:24, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 08:56:24, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2023-02-24 08:56:24, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 08:56:24, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 08:56:24, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 08:56:24, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 08:56:24, code=SNOMED/336623009, ...)
# Event(time=2023-02-24 08:59:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 08:59:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 08:59:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 08:59:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 08:59:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 08:59:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 08:59:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:04:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:04:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:04:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:04:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:04:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:04:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:04:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:09:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:09:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:09:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:09:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:09:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:09:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:09:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:14:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:14:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:14:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:14:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:14:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:14:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:14:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:18:00, code=RxNorm/311700, ...)
# Event(time=2023-02-24 09:19:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:19:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:19:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:19:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:19:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:19:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:19:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:19:00, code=RxNorm/727759, ...)
# Event(time=2023-02-24 09:21:00, code=RxNorm/238082, ...)
# Event(time=2023-02-24 09:24:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:24:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:24:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:24:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:24:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:24:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:24:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:29:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:29:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:29:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:29:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:29:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:29:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:29:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:34:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:34:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:34:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:34:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:34:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:34:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:34:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:39:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:39:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:39:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:39:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:39:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:39:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:39:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:41:00, code=RxNorm/311700, ...)
# Event(time=2023-02-24 09:44:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:44:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:44:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:44:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:44:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:44:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:44:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:49:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2023-02-24 09:49:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2023-02-24 09:49:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2023-02-24 09:49:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:49:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2023-02-24 09:49:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2023-02-24 09:49:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2023-02-24 09:50:00, code=RxNorm/238082, ...)
# Event(time=2023-02-24 09:54:00, code=LOINC/2708-6//UCUM/%, ...)
# ...
# Event(time=2020-03-31 11:59:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2020-03-31 11:59:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-03-31 11:59:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-03-31 11:59:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-03-31 12:30:00, code=SNOMED/293586001, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/68518-0//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/68519-8//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/68520-6//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA15694-5//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA15695-2//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18876-5//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18891-4//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18926-8//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18927-6//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18928-4//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18929-2//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18930-0//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18931-8//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18932-6//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18933-4//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA18934-2//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA6270-8//None/No matching concept, ...)
# Event(time=2020-03-31 12:46:39, code=LOINC/LA6270-8//None/No matching concept, ...)
# Event(time=2020-03-31 12:51:00, code=RxNorm/313782, ...)
# Event(time=2020-03-31 12:53:00, code=LOINC/44250-9, ...)
# Event(time=2020-03-31 12:53:00, code=LOINC/44255-8, ...)
# Event(time=2020-03-31 12:53:00, code=LOINC/44261-6, ...)
# Event(time=2020-03-31 12:53:00, code=LOINC/73831-0//None/No matching concept, ...)
# Event(time=2020-03-31 12:53:00, code=LOINC/73831-0//None/No matching concept, ...)
# Event(time=2020-03-31 12:53:00, code=LOINC/73832-8//None/No matching concept, ...)
# Event(time=2020-03-31 12:53:00, code=LOINC/73832-8//None/No matching concept, ...)
# Event(time=2020-03-31 12:59:00, code=LOINC/56888-1, ...)
# Event(time=2020-03-31 12:59:00, code=LOINC/56888-1, ...)
# Event(time=2020-03-31 13:53:47, code=PCORNet/Generic-NI, ...)
# Event(time=2020-04-18 00:00:00, code=ICD10CM/G44.209, ...)
# Event(time=2020-04-19 00:00:00, code=RxNorm/315223, ...)
# Event(time=2020-08-13 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2020-08-13 00:00:00, code=SNOMED/34043003, ...)
# Event(time=2020-08-13 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2020-08-13 13:04:30, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-08-13 13:04:30, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-08-13 13:04:30, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-08-13 13:04:30, code=Visit/OMOP4822458, ...)
# Event(time=2020-08-13 13:15:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-08-13 13:15:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-08-13 13:15:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-08-13 13:15:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-08-13 13:28:00, code=SNOMED/305058001, ...)
# Event(time=2020-08-13 13:28:00, code=SNOMED/34043003, ...)
# Event(time=2020-08-13 14:04:28, code=PCORNet/Generic-NI, ...)
# Event(time=2020-10-20 00:00:00, code=ICD10CM/N64.4, ...)
# Event(time=2020-10-20 00:00:00, code=ICD10CM/N64.4, ...)
# Event(time=2020-10-20 00:00:00, code=RxNorm/1366116, ...)
# Event(time=2020-10-20 00:00:00, code=RxNorm/1366116, ...)
# Event(time=2020-10-20 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2020-10-20 14:15:00, code=ICD10CM/N64.4, ...)
# Event(time=2020-10-20 14:15:00, code=ICD10CM/N64.4, ...)
# Event(time=2020-10-20 14:20:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2020-10-20 14:20:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-10-20 14:20:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2020-10-20 14:20:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2020-10-20 14:20:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-10-20 14:20:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-10-20 14:20:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-10-20 14:20:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2020-10-20 14:26:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2020-10-20 14:26:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-10-20 14:26:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-10-20 14:26:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-10-20 14:26:00, code=LOINC/9304-7//UCUM//min, ...)
# Event(time=2020-10-20 14:26:00, code=Visit/ER, ...)
# Event(time=2020-10-20 15:04:00, code=CMS Place of Service/12, ...)
# Event(time=2020-12-13 00:00:00, code=RxNorm/1367410, ...)
# Event(time=2020-12-15 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2020-12-15 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2020-12-15 13:03:08, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2020-12-15 13:03:08, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-12-15 13:03:08, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-12-15 13:03:08, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-12-15 13:03:08, code=Visit/OMOP4822458, ...)
# Event(time=2020-12-15 13:23:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2020-12-15 13:23:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2020-12-15 13:23:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2020-12-15 13:23:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2020-12-15 13:23:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2020-12-15 13:47:22, code=PCORNet/Generic-NI, ...)
# Event(time=2020-12-19 00:00:00, code=CPT4/77062, ...)
# Event(time=2021-01-28 00:00:00, code=ICD10CM/N62, ...)
# Event(time=2021-01-28 00:00:00, code=ICD10CM/N62, ...)
# Event(time=2021-01-28 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2021-01-28 14:03:19, code=LOINC/29463-7//UCUM/[oz_av], ...)
# Event(time=2021-01-28 14:03:19, code=LOINC/39156-5//UCUM/kg/m2, ...)
# Event(time=2021-01-28 14:03:19, code=LOINC/8277-6//UCUM/m2, ...)
# Event(time=2021-01-28 14:03:19, code=LOINC/8302-2//UCUM/[in_us], ...)
# Event(time=2021-01-28 14:03:19, code=Visit/OMOP4822458, ...)
# Event(time=2021-01-28 14:12:00, code=LOINC/29463-7//UCUM/[oz_av], ...)
# Event(time=2021-01-28 14:12:00, code=LOINC/8302-2//UCUM/[in_us], ...)
# Event(time=2021-01-28 14:36:52, code=PCORNet/Generic-NI, ...)
# Event(time=2021-01-30 00:00:00, code=ICD10CM/N62, ...)
# Event(time=2021-09-17 00:00:00, code=ICD10CM/R19.8, ...)
# Event(time=2021-09-17 00:00:00, code=ICD10CM/R19.8, ...)
# Event(time=2021-09-17 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2021-09-17 14:28:09, code=Visit/OMOP4822458, ...)
# Event(time=2021-09-17 15:20:54, code=PCORNet/Generic-NI, ...)
# Event(time=2021-09-28 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2021-09-28 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2021-09-28 13:13:14, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2021-09-28 13:13:14, code=Visit/OP, ...)
# Event(time=2021-09-28 13:56:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2021-09-28 14:11:53, code=PCORNet/Generic-NI, ...)
# Event(time=2021-10-06 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2021-10-06 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2021-10-06 11:03:19, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2021-10-06 11:03:19, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2021-10-06 11:03:19, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2021-10-06 11:03:19, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2021-10-06 11:03:19, code=Visit/OMOP4822458, ...)
# Event(time=2021-10-06 13:11:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2021-10-06 13:11:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2021-10-06 13:11:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2021-10-06 13:11:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2021-10-06 13:11:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2021-10-06 13:47:37, code=PCORNet/Generic-NI, ...)
# Event(time=2022-01-10 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2022-03-04 00:00:00, code=CPT4/93010, ...)
# Event(time=2022-03-04 00:00:00, code=ICD10CM/M79.18, ...)
# Event(time=2022-03-04 00:00:00, code=ICD10CM/R05.8, ...)
# Event(time=2022-03-04 00:00:00, code=ICD10CM/R07.9, ...)
# Event(time=2022-03-04 00:00:00, code=ICD10CM/R68.89, ...)
# Event(time=2022-03-04 00:00:00, code=ICD10CM/R68.89, ...)
# Event(time=2022-03-04 21:26:00, code=ICD10CM/J11.1, ...)
# Event(time=2022-03-04 21:26:00, code=ICD10CM/R05.9, ...)
# Event(time=2022-03-04 21:38:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2022-03-04 21:38:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2022-03-04 21:38:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2022-03-04 21:38:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2022-03-04 21:38:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2022-03-04 21:38:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2022-03-04 21:38:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2022-03-04 21:38:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2022-03-04 21:41:00, code=CPT4/93000, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/78199-7, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/8625-6//UCUM/ms, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/8626-4//UCUM/deg, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/8633-0//UCUM/ms, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/8634-8//UCUM/ms, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/8636-3//UCUM/ms, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/8638-9//UCUM/deg, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/8894-8, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/8897-1, ...)
# Event(time=2022-03-04 21:41:00, code=LOINC/9997-8//UCUM/deg, ...)
# Event(time=2022-03-05 00:00:00, code=CPT4/71046, ...)
# Event(time=2022-03-05 00:00:00, code=ICD10CM/R05.9, ...)
# Event(time=2022-03-05 00:00:00, code=ICD10CM/R06.02, ...)
# Event(time=2022-03-05 00:54:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2022-03-05 00:54:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2022-03-05 00:54:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2022-03-05 00:54:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2022-03-05 00:54:00, code=LOINC/9304-7//UCUM//min, ...)
# Event(time=2022-03-05 00:54:00, code=Visit/ER, ...)
# Event(time=2022-03-05 00:59:00, code=CPT4/71046, ...)
# Event(time=2022-03-05 01:55:00, code=RxNorm/197805, ...)
# Event(time=2022-03-05 01:55:00, code=RxNorm/313782, ...)
# Event(time=2022-03-05 01:56:00, code=RxNorm/197397, ...)
# Event(time=2022-03-05 02:10:00, code=LOINC/34487-9, ...)
# Event(time=2022-03-05 02:10:00, code=LOINC/40982-1, ...)
# Event(time=2022-03-05 02:10:00, code=LOINC/94500-6, ...)
# Event(time=2022-03-05 02:57:00, code=CMS Place of Service/12, ...)
# Event(time=2022-04-14 00:00:00, code=SNOMED/305058001, ...)
# Event(time=2022-04-14 00:00:00, code=SNOMED/34043003, ...)
# Event(time=2022-04-14 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2022-04-14 14:50:22, code=Visit/OMOP4822458, ...)
# Event(time=2022-04-14 15:12:04, code=PCORNet/Generic-NI, ...)
# Event(time=2022-04-15 00:00:00, code=SNOMED/365981007, ...)
# Event(time=2022-10-11 00:00:00, code=CPT4/73590, ...)
# Event(time=2022-10-11 00:00:00, code=CPT4/73610, ...)
# Event(time=2022-10-11 00:00:00, code=ICD10CM/M25.571, ...)
# Event(time=2022-10-11 00:00:00, code=ICD10CM/M25.571, ...)
# Event(time=2022-10-11 00:00:00, code=ICD10CM/M79.661, ...)
# Event(time=2022-10-11 00:00:00, code=ICD10CM/R93.6, ...)
# Event(time=2022-10-11 00:00:00, code=RxNorm/1148399, ...)
# Event(time=2022-10-11 00:00:00, code=RxNorm/197806, ...)
# Event(time=2022-10-11 09:28:00, code=ICD10CM/M25.521, ...)
# Event(time=2022-10-11 09:28:00, code=ICD10CM/M25.571, ...)
# Event(time=2022-10-11 09:28:00, code=ICD10CM/M25.571, ...)
# Event(time=2022-10-11 09:30:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2022-10-11 09:30:00, code=LOINC/55284-4//None/No matching concept, ...)
# Event(time=2022-10-11 09:30:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2022-10-11 09:30:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2022-10-11 09:30:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2022-10-11 09:30:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2022-10-11 09:30:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2022-10-11 09:30:00, code=LOINC/9279-1//UCUM//min, ...)
# Event(time=2022-10-11 11:28:00, code=LOINC/8310-5//UCUM/[degF], ...)
# Event(time=2022-10-11 11:28:00, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2022-10-11 11:28:00, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2022-10-11 11:28:00, code=LOINC/8867-4//UCUM//min, ...)
# Event(time=2022-10-11 11:28:00, code=LOINC/9304-7//UCUM//min, ...)
# Event(time=2022-10-11 11:28:00, code=Visit/ER, ...)
# Event(time=2022-10-11 11:30:00, code=CPT4/73590, ...)
# Event(time=2022-10-11 11:40:00, code=ICD10CM/M25.521, ...)
# Event(time=2022-10-11 11:40:00, code=ICD10CM/M25.571, ...)
# Event(time=2022-10-11 11:40:00, code=ICD10CM/M25.571, ...)
# Event(time=2022-10-11 11:41:00, code=Visit/ER, ...)
# Event(time=2022-10-11 11:41:14, code=LOINC/63503-7, ...)
# Event(time=2022-10-11 11:45:00, code=RxNorm/313782, ...)
# Event(time=2022-10-11 11:48:00, code=LOINC/2708-6//UCUM/%, ...)
# Event(time=2022-10-11 11:48:00, code=LOINC/59408-5//UCUM/%, ...)
# Event(time=2022-10-11 13:49:00, code=CPT4/73610, ...)
# Event(time=2022-10-11 15:13:00, code=CMS Place of Service/12, ...)
# Event(time=2022-10-11 23:59:00, code=CMS Place of Service/12, ...)
#
# 1204
# Event(time=2007-03-18 00:00:00, code=Ethnicity/Unknown, ...)
# Event(time=2007-03-18 00:00:00, code=Gender/M, ...)
# Event(time=2007-03-18 00:00:00, code=MEDS_BIRTH, ...)
# Event(time=2007-03-18 00:00:00, code=Race/Unknown, ...)
# Event(time=2018-03-25 00:00:00, code=CPT4/93000, ...)
# Event(time=2018-03-25 00:00:00, code=CPT4/93303, ...)
# Event(time=2018-03-25 00:00:00, code=CPT4/93320, ...)
# Event(time=2018-03-25 00:00:00, code=CPT4/93325, ...)
# Event(time=2018-03-25 00:00:00, code=ICD10CM/R01.1, ...)
# Event(time=2018-03-25 09:00:00, code=Visit/OP, ...)
# Event(time=2020-02-16 00:00:00, code=CPT4/93000, ...)
# Event(time=2020-02-16 00:00:00, code=CPT4/93306, ...)
# Event(time=2020-02-16 00:00:00, code=ICD10CM/R00.2, ...)
# Event(time=2020-02-16 00:00:00, code=ICD10CM/R01.1, ...)
# Event(time=2020-02-16 14:15:00, code=Visit/OP, ...)
# Event(time=2023-11-05 00:00:00, code=CPT4/93000, ...)
# Event(time=2023-11-05 00:00:00, code=CPT4/93000, ...)
# Event(time=2023-11-05 00:00:00, code=CPT4/93306, ...)
# Event(time=2023-11-05 00:00:00, code=ICD10CM/R01.1, ...)
# Event(time=2023-11-05 00:00:00, code=ICD10CM/R01.1, ...)
# Event(time=2023-11-05 00:00:00, code=ICD10CM/R01.1, ...)
# Event(time=2023-11-05 00:00:00, code=ICD10CM/R01.1, ...)
# Event(time=2023-11-05 14:18:57, code=Visit/OMOP4822458, ...)
# Event(time=2023-11-05 15:36:27, code=PCORNet/Generic-NI, ...)
# Event(time=2023-11-05 16:15:00, code=Visit/OP, ...)
# Event(time=2023-11-05 16:15:19, code=LOINC/63503-7, ...)
# Event(time=2023-11-05 23:59:00, code=CMS Place of Service/12, ...)
#
# 1309
# Event(time=1968-06-09 00:00:00, code=Ethnicity/Not Hispanic, ...)
# Event(time=1968-06-09 00:00:00, code=Gender/M, ...)
# Event(time=1968-06-09 00:00:00, code=MEDS_BIRTH, ...)
# Event(time=1968-06-09 00:00:00, code=Race/Unknown, ...)
# Event(time=2019-03-10 10:39:00.100000, code=Visit/OP, ...)
# Event(time=2019-03-10 10:39:00.100010, code=CMS Place of Service/12, ...)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 18
#      16 print(subject_id)
#      17 for event in subject.events:
# ---> 18     print(event)
#      19 print()
#      20 continue
#
# KeyboardInterrupt:

# %%
'''
Top 10 last event codes:
Race/Unknown: 1078408
PCORNet/Generic-NI: 673133
LOINC/63503-7: 569830
Visit/OP: 439523
CMS Place of Service/12: 232716
MEDS_DEATH: 211509
SNOMED/365981007: 198533
Race/UNK: 177163
ICD10CM/L82.00: 80669
ICD10CM/D48.50: 76641
'''
# Out:
# Event(time=2015-12-27 00:00:00, code=Ethnicity/Unknown, ...)
# Event(time=2015-12-27 00:00:00, code=Gender/M, ...)
# Event(time=2015-12-27 00:00:00, code=MEDS_BIRTH, ...)
# Event(time=2015-12-27 00:00:00, code=Race/Unknown, ...)
# Event(time=2016-01-12 00:00:00, code=CPT4/93000, ...)
# Event(time=2016-01-12 00:00:00, code=ICD10CM/R01.10, ...)
# Event(time=2016-01-12 09:26:50.453000, code=ICD10CM/R01.1, ...)
# Event(time=2016-01-12 12:00:00, code=Visit/OP, ...)
# Event(time=2016-01-12 12:36:30.063000, code=SNOMED/365932005//UCUM/%, ...)
# Event(time=2016-01-12 12:36:30.070000, code=LOINC/29463-7//UCUM/[oz_av], ...)
# Event(time=2016-01-12 12:50:56.300000, code=LOINC/18686-6, ...)
# Event(time=2016-01-12 12:50:56.307000, code=LOINC/8867-4, ...)
# Event(time=2016-01-12 12:50:56.310000, code=LOINC/8480-6//UCUM/mm[Hg], ...)
# Event(time=2016-01-12 12:50:56.317000, code=LOINC/8462-4//UCUM/mm[Hg], ...)
# Event(time=2016-01-12 12:51:20.290000, code=LOINC/42588-4, ...)
# Event(time=2016-01-12 12:51:20.290000, code=SNOMED/409137002, ...)
